# %%
import pandas as pd

csv_todisplay = './combined_output.csv'
df = pd.read_csv(csv_todisplay)
print(df)
# Out:
#                                       Email  \
# 0    22090001@alumno.utmetropolitana.edu.mx
# 1    22090002@alumno.utmetropolitana.edu.mx
# 2    22090003@alumno.utmetropolitana.edu.mx
# 3    22090004@alumno.utmetropolitana.edu.mx
# 4    22090005@alumno.utmetropolitana.edu.mx
# ..                                      ...
# 843  22090995@alumno.utmetropolitana.edu.mx
# 844  22090997@alumno.utmetropolitana.edu.mx
# 845  22090998@alumno.utmetropolitana.edu.mx
# 846  22090999@alumno.utmetropolitana.edu.mx
# 847  22091035@alumno.utmetropolitana.edu.mx
#
#                                 Nombre  Ha experimentado.Angustia  \
# 0    YAM ALVARADO BARBARA ALEJANDRINA                       False
# 1         FAULK ESTRADA JEREMY GABRIEL                      False
# 2          MUKUL KANTUN INGRID ABIGAIL                      False
# 3             MEX  MAY ELIEZER AZARIAS                       True
# 4     MALDONADO FERREYRA TANYA SHERENI                      False
# ...
